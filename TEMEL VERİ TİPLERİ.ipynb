# %% [markdown]
# # Temel Veri Tipleri (Basic Data Types)

# %%
# integer tam sayılar
2
# Out:
# 2

# %%
# float kesirli sayılar
2.3
# Out:
# 2.3

# %%
# Boolean Daha ileriki konularda if-else mantığını gördüğümüzde daha iyi oturacak bir veri tipi. Özetle bir şeyin doğru (True) veya yanlış (False) olduğunu belirten bir yapı
2<1
# Out:
# False

# %%
3<4
# Out:
# True

# %%
# type()


# Objelerin tiplerine type() ile bakabiliriz

int(2.4)
# Out:
# 2

# %%
float()
# Out:
# 0.0
